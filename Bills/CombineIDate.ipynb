# %%
'''
Author: Conny Zhou
Email: junyi.zhou@emory.edu
Last Updated: 01/25/2023
'''

import boto3
import pandas as pd

def download_file_from_s3(bucket, object_name, local_file_name):
    """
    Download a file from S3 to the local file system.

    :param bucket: Name of the S3 bucket
    :param object_name: S3 object name
    :param local_file_name: Local file name to save the downloaded file
    """
    s3_client = boto3.client('s3')
    s3_client.download_file(bucket, object_name, local_file_name)

bucket_name = 'myukdata'
s3_file_names = ['Bills/BillLatestStage_Date/BillsLatestStage_Date.csv', 'Bills/BillLatestStage_ID/BillsLatestStage_ID.csv']
local_file_names = ['BillsLatestStage_Date.csv', 'BillsLatestStage_ID.csv']

# Download files
for s3_file, local_file in zip(s3_file_names, local_file_names):
    download_file_from_s3(bucket_name, s3_file, local_file)

# Read into pandas DataFrames
date = pd.read_csv(local_file_names[0])
id = pd.read_csv(local_file_names[1])

# %%
print(date.info())
print(id.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3431 entries, 0 to 3430
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   billId                      3431 non-null   int64
#  1   shortTitle                  3431 non-null   object
#  2   currentHouse                3431 non-null   object
#  3   originatingHouse            3431 non-null   object
#  4   lastUpdate                  3431 non-null   object
#  5   billWithdrawn               50 non-null     object
#  6   isDefeated                  3431 non-null   bool
#  7   billTypeId                  3431 non-null   int64
#  8   introducedSessionId         3431 non-null   int64
#  9   includedSessionIds          3431 non-null   object
#  10  isAct                       3431 non-null   bool
#  11  currentStage.id             3431 non-null   int64
#  12  currentStage.stageId        3431 non-null   int64
#  13  currentStage.sessionId      3431 non-null   int64
#  14  currentStage.description    3431 non-null   object
#  15  currentStage.abbreviation   3431 non-null   object
#  16  currentStage.house          3431 non-null   object
#  17  currentStage.stageSittings  3431 non-null   object
#  18  currentStage.sortOrder      3431 non-null   int64
# dtypes: bool(2), int64(7), object(10)
# memory usage: 462.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4038 entries, 0 to 4037
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   member.memberId             3987 non-null   float64
#  1   billId                      3988 non-null   float64
#  2   longTitle                   3315 non-null   object
#  3   summary                     428 non-null    object
#  4   petitioningPeriod           32 non-null     object
#  5   petitionInformation         39 non-null     object
#  6   agent                       0 non-null      float64
#  7   shortTitle                  3431 non-null   object
#  8   currentHouse                3431 non-null   object
#  9   originatingHouse            3431 non-null   object
#  10  lastUpdate                  3431 non-null   object
#  11  billWithdrawn               50 non-null     object
#  12  isDefeated                  3431 non-null   object
#  13  billTypeId                  3431 non-null   float64
#  14  introducedSessionId         3431 non-null   float64
#  15  includedSessionIds          3431 non-null   object
#  16  isAct                       3431 non-null   object
#  17  currentStage.id             3431 non-null   float64
#  18  currentStage.sessionId      3431 non-null   float64
#  19  currentStage.description    3431 non-null   object
#  20  currentStage.abbreviation   3431 non-null   object
#  21  currentStage.house          3431 non-null   object
#  22  currentStage.stageSittings  3431 non-null   object
#  23  currentStage.sortOrder      3431 non-null   float64
#  24  member                      0 non-null      float64
#  25  sortOrder                   1 non-null      float64
#  26  organisation.name           1 non-null      object
#  27  organisation.url            1 non-null      object
# dtypes: float64(10), object(18)
# memory usage: 883.4+ KB
# None

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    billId                                       shortTitle_x currentHouse_x  \
# 0      29                        Alcohol Labelling Bill [HL]          Lords
# 1      35  Development Orders (Microgeneration) (formerly...          Lords
# 2      63               Royal Commission (Slavery) Bill [HL]          Lords
# 3      37  European Union (Implications of Withdrawal) Bi...          Lords
# 4      54                       Light Bulb (Regulation) Bill        Commons
#
#   originatingHouse_x         lastUpdate_x billWithdrawn_x  isDefeated_x  \
# 0              Lords  2007-10-10T09:11:00             NaN         False
# 1              Lords  2007-10-13T16:36:00             NaN         False
# 2              Lords  2007-10-13T17:02:00             NaN         False
# 3              Lords  2007-10-13T17:36:00             NaN         False
# 4            Commons  2007-10-19T12:28:00             NaN         False
#
#    billTypeId_x  introducedSessionId_x includedSessionIds_x  isAct_x  \
# 0             2                     20                 [20]    False
# 1             2                     20                 [20]    False
# 2             2                     20                 [20]    False
# 3             2                     20                 [20]    False
# 4             8                     20                 [20]    False
#
#    currentStage.id_x  currentStage.stageId  currentStage.sessionId_x  \
# 0                146                     2                        20
# 1                170                     3                        20
# 2              12981                     2                        20
# 3                177                     2                        20
# 4              12972                     7                        20
#
#   currentStage.description_x currentStage.abbreviation_x currentStage.house_x  \
# 0                2nd reading                          2R                Lords
# 1            Committee stage                          CS                Lords
# 2                2nd reading                          2R                Lords
# 3                2nd reading                          2R                Lords
# 4                2nd reading                          2R              Commons
#
#                         currentStage.stageSittings_x  \
# 0  [{'id': 5, 'stageId': 2, 'billStageId': 146, '...
# 1  [{'id': 25, 'stageId': 3, 'billStageId': 170, ...
# 2                                                 []
# 3  [{'id': 32, 'stageId': 2, 'billStageId': 177, ...
# 4                                                 []
#
#    currentStage.sortOrder_x  member.memberId  \
# 0                         2           2570.0
# 1                         3           3271.0
# 2                         2           3364.0
# 3                         2           3153.0
# 4                         2           1412.0
#
#                                            longTitle summary  \
# 0  To make provision for the labelling of alcohol...     NaN
# 1  Make provision for a review of permitted devel...     NaN
# 2  Make provision for the establishment of a Roya...     NaN
# 3  Establish a Committee of Inquiry into the impl...     NaN
# 4                                                NaN     NaN
#
#   petitioningPeriod petitionInformation  agent  \
# 0               NaN                 NaN    NaN
# 1               NaN                 NaN    NaN
# 2               NaN                 NaN    NaN
# 3               NaN                 NaN    NaN
# 4               NaN                 NaN    NaN
#
#                                         shortTitle_y currentHouse_y  \
# 0                        Alcohol Labelling Bill [HL]          Lords
# 1  Development Orders (Microgeneration) (formerly...          Lords
# 2               Royal Commission (Slavery) Bill [HL]          Lords
# 3  European Union (Implications of Withdrawal) Bi...          Lords
# 4                       Light Bulb (Regulation) Bill        Commons
#
#   originatingHouse_y         lastUpdate_y billWithdrawn_y isDefeated_y  \
# 0              Lords  2007-10-10T09:11:00             NaN        False
# 1              Lords  2007-10-13T16:36:00             NaN        False
# 2              Lords  2007-10-13T17:02:00             NaN        False
# 3              Lords  2007-10-13T17:36:00             NaN        False
# 4            Commons  2007-10-19T12:28:00             NaN        False
#
#    billTypeId_y  introducedSessionId_y includedSessionIds_y isAct_y  \
# 0           2.0                   20.0                 [20]   False
# 1           2.0                   20.0                 [20]   False
# 2           2.0                   20.0                 [20]   False
# 3           2.0                   20.0                 [20]   False
# 4           8.0                   20.0                 [20]   False
#
#    currentStage.id_y  currentStage.sessionId_y currentStage.description_y  \
# 0              146.0                      20.0                2nd reading
# 1              170.0                      20.0            Committee stage
# 2            12981.0                      20.0                2nd reading
# 3              177.0                      20.0                2nd reading
# 4            12972.0                      20.0                2nd reading
#
#   currentStage.abbreviation_y currentStage.house_y  \
# 0                          2R                Lords
# 1                          CS                Lords
# 2                          2R                Lords
# 3                          2R                Lords
# 4                          2R              Commons
#
#                         currentStage.stageSittings_y  \
# 0  [{'id': 5, 'stageId': 2, 'billStageId': 146, '...
# 1  [{'id': 25, 'stageId': 3, 'billStageId': 170, ...
# 2                                                 []
# 3  [{'id': 32, 'stageId': 2, 'billStageId': 177, ...
# 4                                                 []
#
#    currentStage.sortOrder_y  member  sortOrder organisation.name  \
# 0                       2.0     NaN        NaN               NaN
# 1                       3.0     NaN        NaN               NaN
# 2                       2.0     NaN        NaN               NaN
# 3                       2.0     NaN        NaN               NaN
# 4                       2.0     NaN        NaN               NaN
#
#   organisation.url
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
#Initial attempt. You can ignore this
df = pd.merge(date, id, on=['billId'])

# %%
df['shortTitle_x']
df['shortTitle_y']
# Count of equal items
equal_count = (df['shortTitle_x'] == df['shortTitle_y']).sum()
print('Number of equal items:', equal_count)

# Count of unequal items
unequal_count = (df['shortTitle_x'] != df['shortTitle_y']).sum()
print('Number of unequal items:', unequal_count)
# Out:
# Number of equal items: 3381
# Number of unequal items: 607

# %%
df[df['shortTitle_x'] != df['shortTitle_y']]['shortTitle_y'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 607 entries, 32 to 3987
# Series name: shortTitle_y
# Non-Null Count  Dtype
# --------------  -----
# 0 non-null      object
# dtypes: object(1)
# memory usage: 9.5+ KB

# %%
#This here is the new outerjoin method while replacing some of the null value with the other column
result = date.merge(id, on='billId', how='outer',suffixes=('_left', '_right'))
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4088 entries, 0 to 4087
# Data columns (total 46 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   billId                            4038 non-null   float64
#  1   shortTitle_left                   4038 non-null   object
#  2   currentHouse_left                 4038 non-null   object
#  3   originatingHouse_left             4038 non-null   object
#  4   lastUpdate_left                   4038 non-null   object
#  5   billWithdrawn_left                50 non-null     object
#  6   isDefeated_left                   4038 non-null   object
#  7   billTypeId_left                   4038 non-null   float64
#  8   introducedSessionId_left          4038 non-null   float64
#  9   includedSessionIds_left           4038 non-null   object
#  10  isAct_left                        4038 non-null   object
#  11  currentStage.id_left              4038 non-null   float64
#  12  currentStage.stageId              4038 non-null   float64
#  13  currentStage.sessionId_left       4038 non-null   float64
#  14  currentStage.description_left     4038 non-null   object
#  15  currentStage.abbreviation_left    4038 non-null   object
#  16  currentStage.house_left           4038 non-null   object
#  17  currentStage.stageSittings_left   4038 non-null   object
#  18  currentStage.sortOrder_left       4038 non-null   float64
#  19  member.memberId                   3987 non-null   float64
#  20  longTitle                         3315 non-null   object
#  21  summary                           428 non-null    object
#  22  petitioningPeriod                 32 non-null     object
#  23  petitionInformation               39 non-null     object
#  24  agent                             0 non-null      float64
#  25  shortTitle_right                  3431 non-null   object
#  26  currentHouse_right                3431 non-null   object
#  27  originatingHouse_right            3431 non-null   object
#  28  lastUpdate_right                  3431 non-null   object
#  29  billWithdrawn_right               50 non-null     object
#  30  isDefeated_right                  3431 non-null   object
#  31  billTypeId_right                  3431 non-null   float64
#  32  introducedSessionId_right         3431 non-null   float64
#  33  includedSessionIds_right          3431 non-null   object
#  34  isAct_right                       3431 non-null   object
#  35  currentStage.id_right             3431 non-null   float64
#  36  currentStage.sessionId_right      3431 non-null   float64
#  37  currentStage.description_right    3431 non-null   object
#  38  currentStage.abbreviation_right   3431 non-null   object
#  39  currentStage.house_right          3431 non-null   object
#  40  currentStage.stageSittings_right  3431 non-null   object
#  41  currentStage.sortOrder_right      3431 non-null   float64
#  42  member                            0 non-null      float64
#  43  sortOrder                         1 non-null      float64
#  44  organisation.name                 1 non-null      object
#  45  organisation.url                  1 non-null      object
# dtypes: float64(16), object(30)
# memory usage: 1.5+ MB

# %%
# Loop through each column and apply the logic
for column in result.columns:
    # Check if the column ends with '_left'
    if column.endswith('_left'):
        # Extract the base name of the column (without '_left')
        base_column_name = column[:-5]
        # Replace NaN in the '_left' column with values from the '_right' column
        result[column] = result[column].fillna(result[base_column_name + '_right'])
        # Drop the '_right' column
        result.drop(base_column_name + '_right', axis=1, inplace=True)
        # Rename '_left' column to original name
        result.rename(columns={column: base_column_name}, inplace=True)


result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4088 entries, 0 to 4087
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   billId                      4038 non-null   float64
#  1   shortTitle                  4088 non-null   object
#  2   currentHouse                4088 non-null   object
#  3   originatingHouse            4088 non-null   object
#  4   lastUpdate                  4088 non-null   object
#  5   billWithdrawn               52 non-null     object
#  6   isDefeated                  4088 non-null   bool
#  7   billTypeId                  4088 non-null   float64
#  8   introducedSessionId         4088 non-null   float64
#  9   includedSessionIds          4088 non-null   object
#  10  isAct                       4088 non-null   bool
#  11  currentStage.id             4088 non-null   float64
#  12  currentStage.stageId        4038 non-null   float64
#  13  currentStage.sessionId      4088 non-null   float64
#  14  currentStage.description    4088 non-null   object
#  15  currentStage.abbreviation   4088 non-null   object
#  16  currentStage.house          4088 non-null   object
#  17  currentStage.stageSittings  4088 non-null   object
#  18  currentStage.sortOrder      4088 non-null   float64
#  19  member.memberId             3987 non-null   float64
#  20  longTitle                   3315 non-null   object
#  21  summary                     428 non-null    object
#  22  petitioningPeriod           32 non-null     object
#  23  petitionInformation         39 non-null     object
#  24  agent                       0 non-null      float64
#  25  member                      0 non-null      float64
#  26  sortOrder                   1 non-null      float64
#  27  organisation.name           1 non-null      object
#  28  organisation.url            1 non-null      object
# dtypes: bool(2), float64(11), object(16)
# memory usage: 902.2+ KB

# %%
#Remove rows whose billId is NaN
result = result[result['billId'].notna()]
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4038 entries, 0 to 4037
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   billId                      4038 non-null   float64
#  1   shortTitle                  4038 non-null   object
#  2   currentHouse                4038 non-null   object
#  3   originatingHouse            4038 non-null   object
#  4   lastUpdate                  4038 non-null   object
#  5   billWithdrawn               50 non-null     object
#  6   isDefeated                  4038 non-null   bool
#  7   billTypeId                  4038 non-null   float64
#  8   introducedSessionId         4038 non-null   float64
#  9   includedSessionIds          4038 non-null   object
#  10  isAct                       4038 non-null   bool
#  11  currentStage.id             4038 non-null   float64
#  12  currentStage.stageId        4038 non-null   float64
#  13  currentStage.sessionId      4038 non-null   float64
#  14  currentStage.description    4038 non-null   object
#  15  currentStage.abbreviation   4038 non-null   object
#  16  currentStage.house          4038 non-null   object
#  17  currentStage.stageSittings  4038 non-null   object
#  18  currentStage.sortOrder      4038 non-null   float64
#  19  member.memberId             3987 non-null   float64
#  20  longTitle                   3265 non-null   object
#  21  summary                     404 non-null    object
#  22  petitioningPeriod           1 non-null      object
#  23  petitionInformation         2 non-null      object
#  24  agent                       0 non-null      float64
#  25  member                      0 non-null      float64
#  26  sortOrder                   1 non-null      float64
#  27  organisation.name           1 non-null      object
#  28  organisation.url            1 non-null      object
# dtypes: bool(2), float64(11), object(16)
# memory usage: 891.2+ KB

# %%
print(date['billId'].count())
print(date['billId'].nunique())
print(id['billId'].count())
print(id['billId'].nunique())
#This means that for the id dataset, there are duplicate rows used for single bill with multiple sponsors
# Out:
# 3431
# 3431
# 3988
# 3381

# %%
print(result['billId'].count())
print(result['billId'].nunique())
# Out:
# 4038
# 3431

# %%
#Write the result to csv
result.to_csv('demo.csv', index=False)

# %%
#Save the file to S3
import boto3
import io

def upload_df_to_s3(df, bucket, object_name):
    """
    Upload a DataFrame to an S3 bucket as CSV.

    :param df: DataFrame to upload
    :param bucket: Bucket to upload to
    :param object_name: S3 object name
    :return: True if the DataFrame was uploaded, else False
    """
    # Create a buffer
    csv_buffer = io.StringIO()
    df.to_csv(csv_buffer, index=False)

    # Move to the start of the buffer
    csv_buffer.seek(0)

    # Upload the buffer content to S3
    s3_client = boto3.client('s3')
    try:
        s3_client.put_object(Bucket=bucket, Key=object_name, Body=csv_buffer.getvalue())
    except ClientError as e:
        logging.error(e)
        return False
    return True

bucket_name = 'myukdata'
object_name = 'Bills/BillsLatestStage_Combined/BillsLatestStage_Combined.csv'
upload_df_to_s3(df, bucket_name, object_name)
