# %%
import boto3
import pandas as pd
import numpy as np

# %%
def download_file_from_s3(bucket, object_name, local_file_name):
    """
    Download a file from S3 to the local file system.

    :param bucket: Name of the S3 bucket
    :param object_name: S3 object name
    :param local_file_name: Local file name to save the downloaded file
    """
    # # When using IAM roles, boto3 retrieves credentials from the instance metadata
    # s3_client = boto3.client('s3')

    #When setting up credentials locally, use the following code
    session = boto3.Session()
    s3_client = session.client('s3')

    s3_client.download_file(bucket, object_name, local_file_name)

bucket_name = 'myukdata'
s3_file_name = 'Member/Member/Member.csv'
local_file = 'Member.csv'

download_file_from_s3(bucket_name, s3_file_name, local_file)

# %%
df = pd.read_csv('Member.csv')
df.info()
pd.set_option('display.max_rows', None)
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4788 entries, 0 to 4787
# Data columns (total 33 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   links                                                           4788 non-null   object
#  1   value.id                                                        4788 non-null   int64
#  2   value.nameListAs                                                4788 non-null   object
#  3   value.nameDisplayAs                                             4788 non-null   object
#  4   value.nameFullTitle                                             4788 non-null   object
#  5   value.nameAddressAs                                             1785 non-null   object
#  6   value.latestParty.id                                            4785 non-null   float64
#  7   value.latestParty.name                                          4785 non-null   object
#  8   value.latestParty.abbreviation                                  4650 non-null   object
#  9   value.latestParty.backgroundColour                              4642 non-null   object
#  10  value.latestParty.foregroundColour                              4635 non-null   object
#  11  value.latestParty.isLordsMainParty                              4785 non-null   object
#  12  value.latestParty.isLordsSpiritualParty                         4785 non-null   object
#  13  value.latestParty.governmentType                                3044 non-null   float64
#  14  value.latestParty.isIndependentParty                            4785 non-null   object
#  15  value.gender                                                    4788 non-null   object
#  16  value.latestHouseMembership.membershipFrom                      4785 non-null   object
#  17  value.latestHouseMembership.membershipFromId                    4785 non-null   float64
#  18  value.latestHouseMembership.house                               4788 non-null   int64
#  19  value.latestHouseMembership.membershipStartDate                 4788 non-null   object
#  20  value.latestHouseMembership.membershipEndDate                   3320 non-null   object
#  21  value.latestHouseMembership.membershipEndReason                 2514 non-null   object
#  22  value.latestHouseMembership.membershipEndReasonNotes            320 non-null    object
#  23  value.latestHouseMembership.membershipEndReasonId               2514 non-null   float64
#  24  value.latestHouseMembership.membershipStatus                    0 non-null      float64
#  25  value.thumbnailUrl                                              4788 non-null   object
#  26  value.latestHouseMembership.membershipStatus.statusIsActive     1468 non-null   object
#  27  value.latestHouseMembership.membershipStatus.statusDescription  1468 non-null   object
#  28  value.latestHouseMembership.membershipStatus.statusNotes        5 non-null      object
#  29  value.latestHouseMembership.membershipStatus.statusId           1468 non-null   float64
#  30  value.latestHouseMembership.membershipStatus.status             1468 non-null   float64
#  31  value.latestHouseMembership.membershipStatus.statusStartDate    1468 non-null   object
#  32  value.latestParty                                               0 non-null      float64
# dtypes: float64(8), int64(2), object(23)
# memory usage: 1.2+ MB
#                                                links  value.id  \
# 0  [{'rel': 'self', 'href': '/Members/1', 'method...         1
# 1  [{'rel': 'self', 'href': '/Members/2', 'method...         2
# 2  [{'rel': 'self', 'href': '/Members/3', 'method...         3
# 3  [{'rel': 'self', 'href': '/Members/4', 'method...         4
# 4  [{'rel': 'self', 'href': '/Members/5', 'method...         5
#
#         value.nameListAs         value.nameDisplayAs  \
# 0          Hall, Patrick                Patrick Hall
# 1        Hopkins, Kelvin              Kelvin Hopkins
# 2        Moran, Margaret              Margaret Moran
# 3    Sayeed, Mr Jonathan          Mr Jonathan Sayeed
# 4  Lyell of Markyate, L.  The Lord Lyell of Markyate
#
#                          value.nameFullTitle value.nameAddressAs  \
# 0                               Patrick Hall                 NaN
# 1                             Kelvin Hopkins      Kelvin Hopkins
# 2                             Margaret Moran      Margaret Moran
# 3                         Mr Jonathan Sayeed                 NaN
# 4  The Rt Hon. the Lord Lyell of Markyate QC                 NaN
#
#    value.latestParty.id    value.latestParty.name  \
# 0                  15.0                    Labour
# 1                   8.0               Independent
# 2                   8.0               Independent
# 3                   9.0  Independent Conservative
# 4                   4.0              Conservative
#
#   value.latestParty.abbreviation value.latestParty.backgroundColour  \
# 0                            Lab                             ff0000
# 1                            Ind                             C0C0C0
# 2                            Ind                             C0C0C0
# 3                        Ind Con                             0000FF
# 4                            Con                             0000ff
#
#   value.latestParty.foregroundColour value.latestParty.isLordsMainParty  \
# 0                             ffffff                               True
# 1                             FFFFFF                              False
# 2                             FFFFFF                              False
# 3                             FFFFFF                              False
# 4                             ffffff                               True
#
#   value.latestParty.isLordsSpiritualParty  value.latestParty.governmentType  \
# 0                                   False                               3.0
# 1                                   False                               NaN
# 2                                   False                               NaN
# 3                                   False                               NaN
# 4                                    True                               0.0
#
#   value.latestParty.isIndependentParty value.gender  \
# 0                                False            M
# 1                                 True            M
# 2                                 True            F
# 3                                False            M
# 4                                False            M
#
#   value.latestHouseMembership.membershipFrom  \
# 0                                    Bedford
# 1                                Luton North
# 2                                Luton South
# 3                           Mid Bedfordshire
# 4                                  Life peer
#
#    value.latestHouseMembership.membershipFromId  \
# 0                                         185.0
# 1                                        3589.0
# 2                                        1860.0
# 3                                        1946.0
# 4                                           4.0
#
#    value.latestHouseMembership.house  \
# 0                                  1
# 1                                  1
# 2                                  1
# 3                                  1
# 4                                  2
#
#   value.latestHouseMembership.membershipStartDate  \
# 0                             1997-05-01T00:00:00
# 1                             1997-05-01T00:00:00
# 2                             1997-05-01T00:00:00
# 3                             1997-05-01T00:00:00
# 4                             2005-06-27T00:00:00
#
#   value.latestHouseMembership.membershipEndDate  \
# 0                           2010-05-06T00:00:00
# 1                           2019-11-06T00:00:00
# 2                           2010-05-06T00:00:00
# 3                           2005-05-05T00:00:00
# 4                           2010-08-30T00:00:00
#
#   value.latestHouseMembership.membershipEndReason  \
# 0                                        Defeated
# 1                                   Standing Down
# 2                                         Retired
# 3                                             NaN
# 4                                           Death
#
#   value.latestHouseMembership.membershipEndReasonNotes  \
# 0                                                NaN
# 1                          Dissolution of Parliament
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    value.latestHouseMembership.membershipEndReasonId  \
# 0                                                2.0
# 1                                               12.0
# 2                                               11.0
# 3                                                NaN
# 4                                                1.0
#
#    value.latestHouseMembership.membershipStatus  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#                                   value.thumbnailUrl  \
# 0  https://members-api.parliament.uk/api/Members/...
# 1  https://members-api.parliament.uk/api/Members/...
# 2  https://members-api.parliament.uk/api/Members/...
# 3  https://members-api.parliament.uk/api/Members/...
# 4  https://members-api.parliament.uk/api/Members/...
#
#   value.latestHouseMembership.membershipStatus.statusIsActive  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   value.latestHouseMembership.membershipStatus.statusDescription  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   value.latestHouseMembership.membershipStatus.statusNotes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    value.latestHouseMembership.membershipStatus.statusId  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    value.latestHouseMembership.membershipStatus.status  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   value.latestHouseMembership.membershipStatus.statusStartDate  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    value.latestParty
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
df.drop(columns=['links',
                 'value.nameDisplayAs',
                 'value.nameAddressAs',
                 'value.latestParty.backgroundColour',
                 'value.latestParty.foregroundColour',
                 'value.latestParty.governmentType',
                 'value.latestHouseMembership.membershipStatus',
                 'value.latestHouseMembership.membershipEndReasonId',
                 'value.thumbnailUrl',
                 'value.latestHouseMembership.membershipStatus.statusIsActive',
                 'value.latestHouseMembership.membershipStatus.statusDescription',
                 'value.latestHouseMembership.membershipStatus.statusNotes',
                 'value.latestHouseMembership.membershipStatus.statusId',
                 'value.latestHouseMembership.membershipStatus.status',
                 'value.latestHouseMembership.membershipStatus.statusStartDate',
                 'value.latestParty',
                 'value.latestParty.abbreviation',
                 'value.latestHouseMembership.membershipEndReasonNotes'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4788 entries, 0 to 4787
# Data columns (total 15 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   value.id                                         4788 non-null   int64
#  1   value.nameListAs                                 4788 non-null   object
#  2   value.nameFullTitle                              4788 non-null   object
#  3   value.latestParty.id                             4785 non-null   float64
#  4   value.latestParty.name                           4785 non-null   object
#  5   value.latestParty.isLordsMainParty               4785 non-null   object
#  6   value.latestParty.isLordsSpiritualParty          4785 non-null   object
#  7   value.latestParty.isIndependentParty             4785 non-null   object
#  8   value.gender                                     4788 non-null   object
#  9   value.latestHouseMembership.membershipFrom       4785 non-null   object
#  10  value.latestHouseMembership.membershipFromId     4785 non-null   float64
#  11  value.latestHouseMembership.house                4788 non-null   int64
#  12  value.latestHouseMembership.membershipStartDate  4788 non-null   object
#  13  value.latestHouseMembership.membershipEndDate    3320 non-null   object
#  14  value.latestHouseMembership.membershipEndReason  2514 non-null   object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 561.2+ KB

# %%
df.rename(columns={'value.id': 'memberId',
                     'value.nameListAs': 'fullName',
                     'value.nameFullTitle': 'fullTitle',
                     'value.latestParty.id': 'latestPartyId',
                     'value.latestParty.name': 'partyName',
                     'value.latestParty.isLordsMainParty': 'isLordsMainParty',
                     'value.latestParty.isLordsSpiritualParty': 'isLordsSpiritualParty',
                     'value.latestParty.isIndependentParty': 'isIndependentParty',
                     'value.gender': 'gender',
                     'value.latestHouseMembership.membershipFrom': 'membershipFrom',
                     'value.latestHouseMembership.membershipFromId': 'membershipFromId',
                     'value.latestHouseMembership.house': 'house',
                     'value.latestHouseMembership.membershipStartDate': 'membershipStartDate',
                     'value.latestHouseMembership.membershipEndDate': 'membershipEndDate',
                     'value.latestHouseMembership.membershipEndReason': 'membershipEndReason'}, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4788 entries, 0 to 4787
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   memberId               4788 non-null   int64
#  1   fullName               4788 non-null   object
#  2   fullTitle              4788 non-null   object
#  3   latestPartyId          4785 non-null   float64
#  4   partyName              4785 non-null   object
#  5   isLordsMainParty       4785 non-null   object
#  6   isLordsSpiritualParty  4785 non-null   object
#  7   isIndependentParty     4785 non-null   object
#  8   gender                 4788 non-null   object
#  9   membershipFrom         4785 non-null   object
#  10  membershipFromId       4785 non-null   float64
#  11  house                  4788 non-null   int64
#  12  membershipStartDate    4788 non-null   object
#  13  membershipEndDate      3320 non-null   object
#  14  membershipEndReason    2514 non-null   object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 561.2+ KB
